# %% [markdown]
# for문

# %% [markdown]
# - 반복구조(iteration) : 임의의 문장을 반복해서 실행하는 구조

# %% [markdown]
# - 1~100까지의 난수를 5번 출력하는 프로그램을 작성하시오

# %%
import random #너무 비효율적임

print(random.randint(1, 100))
print(random.randint(1, 100))
print(random.randint(1, 100))
print(random.randint(1, 100))
print(random.randint(1, 100))
# Out:
# 55
# 51
# 35
# 85
# 2

# %%
import random
for i in range(5):
  print(random.randint(1, 100))
# Out:
# 35
# 88
# 97
# 52
# 72

# %%
import random
a = 5
for i in range(a):
  print(random.randint(1, 100))
# Out:
# 14
# 69
# 67
# 59
# 23

# %% [markdown]
# for활용

# %% [markdown]
# - for문은 정해진 횟수만큼 반복해서 문장을 실행
# - 셀 수 있는 것: 범위, 문자열, 리스트, 딕셔너리 등
# - 일반적으로 범위를 가장 많이 사용하며, 범위는 rande() 함수 사용
# - range() 함수: range(시작값, 종료값, 증가값)
#  - 시작값으로 시작해서 증가값 만큼 증가하며 종료값 바로 전까지 값을 생성
#  - 증가값을 입력하지 않으면 증가값은 1
#  - 시작값을 입력하지 않으면 기본 시작값은 0

# %% [markdown]
# - 문자열 출력을 반복하는 프로그램

# %%
for i in range(3):
  print("안녕!")
# Out:
# 안녕!
# 안녕!
# 안녕!

# %% [markdown]
# - for문 값이 변하는 변수

# %%
for a in range(2, 5):
  print(a)
# Out:
# 2
# 3
# 4

# %% [markdown]
# - range 함수에서 증가값이 음수인 경우

# %%
for a in range(10, 1, -3):
  print(a)
# Out:
# 10
# 7
# 4

# %% [markdown]
# - 정수의 합을 구하는 프로그램

# %%
sum = 1+2+3+4+5
print(sum)
# Out:
# 15

# %%
sum = 0
for a in range(1, 6):
  sum += a
  print(sum) #들여쓰기하면 for문에 대해서 결과가 나오게 되고 들여쓰기를 안 하면 별개의 값으로 나오게 됨
# Out:
# 1
# 3
# 6
# 10
# 15

# %% [markdown]
# - 약수를 구하는 프로그램

# %%
num = int(input('정수: '))
for a in range(1, num+1):
  if num % a == 0:
    print(a, end='\t')
# Out:
# 정수: 4
# 1	2	4

# %% [markdown]
# 전 직원의 월급 총액 구하기

# %% [markdown]
# - 직급별 월급이 다름
# - 전체 직원수 변수: employee_num
# - 월급 총액 변수: totoal
# - 2급이상: 본봉 + 상여금(30%)
# - 2급미만: 본봉 + 상여금(20%)

# %%
employee_num = 3
total = 0

for i in range(employee_num):
  rank = int(input('직급: '))
  basic_salary = int(input('본봉: '))
  if rank >=2:
    bonus = basic_salary*0.3
  else:
    bonus = basic_salary*0.2
  salary = basic_salary + bonus
  total += salary
  print(salary)
print('월급총액 : ', total)

# %% [markdown]
# 경진대회 평가 점수 구하기

# %% [markdown]
# - 심사위원들의 평가 점수 합: sum
# - 최고 점수: max_score
# - 조건
#  - 심사위원 5명
#  - 공정성을 위해 최고 점수를 뺀 나머지 점수 평균

# %%
judge_num = 5
sum = 0
max_score = 0

for i in range(judge_num):
  score = int(input(f'심사위원 {i+1} 평가 점수: '))
  sum += score
  if score > max_score:
    max_score = score
sum -= max_score
print('작품 평균 점수: ', sum/(judge_num-1))
# Out:
# 심사위원 1 평가 점수: 3
# 심사위원 2 평가 점수: 5
# 심사위원 3 평가 점수: 1
# 심사위원 4 평가 점수: 2
# 심사위원 5 평가 점수: 5
# 작품 평균 점수:  2.75

# %% [markdown]
# 적정 심박수 구하기

# %% [markdown]
# - 카이보넨 공식: 나이와 안정시 심박수를 이용해 운동에 필요한 적정 심박수를 계산하는 공식
# - 목표 심박수 = ((((220-나이)-안정 시 심박수)*강도)+안정 시 심박수)

# %%
age = int(input('나이: '))
resting_HR = int(input('안정 시 심박수: '))
for a in range(40, 81, 10):
  intensity = a/100
  target_HR = (((220-age)-resting_HR)*intensity)+resting_HR
  print(f'강도 {a}% 목표 심박수: {target_HR}bpm')
# Out:
# 나이: 23
# 안정 시 심박수: 120
# 강도 40% 목표 심박수: 150.8bpm
# 강도 50% 목표 심박수: 158.5bpm
# 강도 60% 목표 심박수: 166.2bpm
# 강도 70% 목표 심박수: 173.9bpm
# 강도 80% 목표 심박수: 181.6bpm

# %% [markdown]
# While문

# %% [markdown]
# While문의 활용

# %% [markdown]
# - 조건식이 참인 동안 문장을 반복해서 실행
# - 거짓이면 종료

# %%
a = 1
while a<=9:
  print(f'{a}회 반복')
  a += 1
# Out:
# 1회 반복
# 2회 반복
# 3회 반복
# 4회 반복
# 5회 반복
# 6회 반복
# 7회 반복
# 8회 반복
# 9회 반복

# %% [markdown]
# - 정수의 합

# %%
sum = 0
a = 1
while a <=10:
  sum += a
  a += 1
print(sum)
# Out:
# 55

# %% [markdown]
# - 입력한 값에 따라 다르게 동작하는 츠로그램
#  - 이름: 문자열로 입력 받음
#  - 나이: 숫자로 입력 받음
#  - 프로그램 종료: 종료 문자열을 입력으로 받음
# - 입력 받은 내용이 숫자 형식인지 판별하는 함수 사용: isdigit()
#  - 문자열이 숫자인지 판별, 숫자 형식이면 true 아니면 false
#  - object.method()
# - 반복문을 빠져 나올때는 break 키워드 사용

# %%
while True:
  answer = input('이름 or 나이 or 종료: ')
  if answer == '종료':
    print('종료합니다.')
    break
  elif answer.isdigit():
    print(f'{answer}세 군요 ')
  else:
    print(f'{answer}님 반갑습니다.')
# Out:
# 이름 or 나이 or 종료: 송에스더
# 송에스더님 반갑습니다.
# 이름 or 나이 or 종료: 23
# 23세 군요
# 이름 or 나이 or 종료: 종료
# 종료합니다.

# %% [markdown]
# 5만원 모으기

# %% [markdown]
# - 하루에 100원 부터 100원씩 추가하여 모을 경우 며칠이 걸리는지 구하는 프로그램
#  - sum: 저금한 총액
#  - money: 일자별로 저금하는 금액
#  - day: 저금한 일수

# %%
sum = 0
money = 100
day = 0

while sum < 50000:
  sum += money
  day += 1
  money += 100

print(day)
# Out:
# 32

# %% [markdown]
# 자리 수 합 구하기

# %% [markdown]
# - 정수 각 자릿수의 합 구하기
#  - 예) 234 -> 2+3+4 = 9

# %%
num = int(input('정수: '))
sum = 0

while num > 0:
  sum += num%10
  num = num//10

print(sum)
# Out:
# 정수: 345
# 12

# %% [markdown]
# 숫자 맞추기 게임

# %% [markdown]
# 컴퓨터가 선택한 수 맞추기
# - 컴퓨터가 무작위로 생성한 정수를 사용자가 맞추는 게임
# - 1~100까지의 랜덤 수 생성 -> answer에 저장
# - 사용자가 수를 입력하면 answer값과 같으면 프로그램 종료
# - 몇 번만에 맞췄는지 확인

# %%
import random

answer = random.randint(1, 100)
times = 0

while True:
  user = int(input('1~100 숫자 입력: '))
  times += 1
  if user == answer:
    break
  elif user < answer:
    print(f'{user}보다 큽니다.')
  else:
    print(f'{user}보다 작습니다.')

print(f'정답입니다. {times}회 만에 맞췄습니다.')
# Out:
# 1~100 숫자 입력: 50
# 50보다 큽니다.
# 1~100 숫자 입력: 12
# 12보다 큽니다.
# 1~100 숫자 입력: 66
# 66보다 큽니다.
# 1~100 숫자 입력: 100
# 100보다 작습니다.
# 1~100 숫자 입력: 234
# 234보다 작습니다.
# 1~100 숫자 입력: 3
# 3보다 큽니다.
# 1~100 숫자 입력: 2
# 2보다 큽니다.
# 1~100 숫자 입력: 5
# 5보다 큽니다.
# 1~100 숫자 입력: 10
# 10보다 큽니다.
# 1~100 숫자 입력: 70
# 70보다 큽니다.
# 1~100 숫자 입력: 75
# 75보다 큽니다.
# 1~100 숫자 입력: 80
# 80보다 큽니다.
# 1~100 숫자 입력: 85
# 85보다 작습니다.
# 1~100 숫자 입력: 84
# 84보다 작습니다.
# 1~100 숫자 입력: 83
# 83보다 작습니다.
# 1~100 숫자 입력: 82
# 정답입니다. 16회 만에 맞췄습니다.

# %% [markdown]
# 사용자가 생각한 수 맞추기

# %%
print('1~100 중 숫자 하나를 정하세요.')
print('이 숫자를 맞혀보겠습니다.')

low = 1
high = 100
times = 0

while True:
  num = (low+high)//2
  answer = input(f'{num}인가요? OK/UP/DOWN:')
  times += 1
  if answer == 'OK':
    break
  elif answer == 'UP':
    low = num+1
  elif answer == 'DOWN':
    high = num-1
  else:
    print('잘못 입력했습니다.')

  print(f'정답입니다. {times}회 만에 맞췄습니다. ')
# Out:
# 1~100 중 숫자 하나를 정하세요.
# 이 숫자를 맞혀보겠습니다.
# 50인가요? OK/UP/DOWN:DOWN
# 정답입니다. 1회 만에 맞췄습니다.
# 25인가요? OK/UP/DOWN:UP
# 정답입니다. 2회 만에 맞췄습니다.
# 37인가요? OK/UP/DOWN:DOWN
# 정답입니다. 3회 만에 맞췄습니다.
# 31인가요? OK/UP/DOWN:DOWN
# 정답입니다. 4회 만에 맞췄습니다.
# 28인가요? OK/UP/DOWN:UP
# 정답입니다. 5회 만에 맞췄습니다.
# 29인가요? OK/UP/DOWN:UP
# 정답입니다. 6회 만에 맞췄습니다.
# 30인가요? OK/UP/DOWN:OK

# %% [markdown]
# 쌍둥이 문제
# - 컴퓨터 1이 선택한 수를 사용자와 컴퓨터 2가 번갈아 가면서 맞추는 프로그램

# %% [markdown]
# 번역기
# - 문장을 입력하면 원하는 국가의 언어로 번역하는 프로그램
# - 영어와 일어를 번역
# - 구글 번역기 라이브러리 설치: googletrans

# %%
# !pip install googletrans

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.6 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=f1dc04dfc7768e516e9f803bd0d79a375876cd4ac7822185ff0d2b34cf03a526
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
# ...

# %%
import googletrans
translator = googletrans.Translator()

# %%
dest = translator.translate('반갑습니다.', dest='en')
print(dest.text)
# Out:
# Nice to meet you.

# %%
src = input('번역할 내용을 입력하세요 : ')
dest = translator.translate(src, dest='en')
print(f'영어 : {dest.text}')
dest = translator.translate(src, dest='ja')
print(f'일어 : {dest.text}')
# Out:
# 번역할 내용을 입력하세요 : 안녕
# 영어 : hi
# 일어 : こんにちは

# %% [markdown]
# 번역기
# - 도착어와 번역할 내용을 입력 받아 동작을 반복적으로 수행하는 번역기
# - 종료 문장 입력시 프로그램 종료

# %%
import googletrans
translator = googletrans.Translator()

# %%
while True:
 lang = input('도착어 선택(영어, 일본어, 독일어, 종료): ')
 if lang=='종료':
   print('종료합니다.')
   break
 elif lang=='영어':
   lang = 'en'
 elif lang=='일본어':
   lang = 'ja'
 elif lang=='독일어':
   lang = 'de'
 else:
   print('잘못 입력했습니다.')
   continue
 src = input('번역할 내용을 입력하세요: ')
 dest = translator.translate(src, dest=lang)
 print(dest.text)
# Out:
# 도착어 선택(영어, 일본어, 독일어, 종료): 영어
# 번역할 내용을 입력하세요: 마신다
# Drink
# 도착어 선택(영어, 일본어, 독일어, 종료): 종료
# 종료합니다.
